# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
train.head()
# Out:
#    Observation         T1    RH_1         T2       RH_2         T3       RH_3  \
# 0         1111  22.700000  37.200  21.000000  38.000000  23.390000  37.290000
# 1         1112  21.500000  41.045  20.500000  39.133333  22.926667  39.526667
# 2         1113  21.666667  38.000  22.600000  35.700000  21.890000  36.590000
# 3         1114  23.290000  38.530  21.671429  38.000000  24.290000  36.200000
# 4         1115  24.000000  42.560  26.830000  34.356000  26.530000  40.333333
#
#           T4       RH_4         T5       RH_5         T6       RH_6      T7  \
# 0  22.832857  34.942857  20.500000  42.826667  12.533333   9.633333  22.060
# 1  21.700000  34.126667  18.633333  44.663333  10.190000  11.926667  20.790
# 2  22.000000  35.530000  19.000000  46.200000  10.360000  21.533333  19.600
# 3  23.100000  35.090000  22.042857  43.625714  10.390000   9.590000  23.390
# 4  24.500000  40.900000  21.500000  49.090000  20.290000   1.000000  23.365
#
# ...

# %%
test.head()
# Out:
#    Observation         T1   RH_1         T2       RH_2         T3       RH_3  \
# 0        50001  21.100000  39.90  19.290000  41.260000  21.500000  40.700000
# 1        50002  22.600000  39.03  20.790000  40.463333  22.290000  38.290000
# 2        50003  21.000000  35.59  19.790000  34.900000  21.166667  35.833333
# 3        50004  20.566667  37.59  20.566667  35.700000  20.166667  37.000000
# 4        50005  21.500000  38.70  18.566667  42.030000  22.500000  38.900000
#
#       T4       RH_4         T5       RH_5        T6       RH_6     T7  \
# 0  18.89  41.200000  18.088889  52.080000  3.200000  92.500000  19.20
# 1  20.29  36.700000  20.760000  43.666667  7.690000  45.256667  20.50
# 2  20.39  33.090000  18.000000  45.700000  7.190000  25.466667  21.10
# 3  22.00  35.326667  17.700000  45.400000  8.960000  32.663333  19.79
# 4  20.00  39.000000  19.633333  48.826667  2.966667  65.263333  20.20
#
#         RH_7         T8       RH_8         T9   RH_9  T_out  Press_mm_hg  \
# ...

# %%
train.describe()
# Out:
#         Observation            T1          RH_1            T2          RH_2  \
# count  15780.000000  15780.000000  15780.000000  15780.000000  15780.000000
# mean    9000.500000     21.683008     40.263077     20.339386     40.426604
# std     4555.437959      1.613157      3.983819      2.199896      4.085470
# min     1111.000000     16.790000     27.023333     16.100000     20.463333
# 25%     5055.750000     20.730000     37.360000     18.790000     37.890000
# 50%     9000.500000     21.600000     39.663333     20.000000     40.500000
# 75%    12945.250000     22.600000     43.090000     21.530000     43.290000
# max    16890.000000     26.260000     63.360000     29.856667     56.026667
#
#                  T3          RH_3            T4          RH_4            T5  \
# count  15780.000000  15780.000000  15780.000000  15780.000000  15780.000000
# mean      22.265359     39.242550     20.853829     39.037623     19.591562
# ...

# %%
train.shape
# Out:
# (15780, 26)

# %%
test.shape
# Out:
# (3945, 25)

# %%
train['Energy'].nunique()
# Out:
# 82

# %%
features = [i for i in test.columns if i not in ['Observation']]

# %%
import xgboost as xgb
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
import math

# %%
def modelfit(model, train_data, train_label, predictors, eval_metric, useTrainCV=True, cv_folds=10, early_stopping_rounds=100):
    
    if useTrainCV:
        xgb_param = model.get_xgb_params()
        params = {
            'objective' : xgb_param['objective'],
            'num_class' : 82,
            'base_score' : xgb_param['base_score'],
            'colsample_bylevel' : xgb_param['colsample_bylevel'],
            'colsample_bytree' : xgb_param['colsample_bytree'],
            'gamma' : xgb_param['gamma'],
            'eta' : xgb_param['learning_rate'],
            'max_delta_step' : xgb_param['max_delta_step'],
            'max_depth' : xgb_param['max_depth'],
            'min_child_weight' : xgb_param['min_child_weight'],
            'alpha' : xgb_param['reg_alpha'],
            'lambda': xgb_param['reg_lambda'],
            'scale_pos_weight' : xgb_param['scale_pos_weight'],
            'subsample' : xgb_param['subsample'],     
        }
        dtrain = xgb.DMatrix(data=train_data[predictors], label=train_label)
        cvresult = xgb.cv(params , dtrain, num_boost_round=model.get_params()['n_estimators'], stratified=True, nfold=cv_folds, metrics=eval_metric, early_stopping_rounds=early_stopping_rounds)
        model.set_params(n_estimators=cvresult.shape[0])
        # print(cvresult)
        print("########### n_estimators = %f" % cvresult.shape[0])
    
    # Fit the algorithm on the data
    model.fit(train_data[predictors], train_label,eval_metric=eval_metric)
        
    # Predict training set:
    train_predictions = model.predict(train_data[predictors])
    
    # Predict X_valid set:
    #valid_predictions = model.predict(X_valid[predictors])
    #valid_predprob = model.predict_proba(X_valid[predictors])[:,1]
        
    # Print model report:
    print("\nModel Report")
    
    print("RMSE score (Train): %f" % math.sqrt(mean_squared_error(train_label, train_predictions)))
    print("r2 score (Train): %f" % r2_score(train_label, train_predictions))
    feat_imp = pd.Series(model.booster().get_fscore()).sort_values(ascending=False)
    feat_imp.plot(kind='bar', title='Feature Importances')
    plt.ylabel('Feature Importance Score')
    return model

# %%
clf1 = xgb.XGBClassifier(objective ='multi:softmax',learning_rate=0.1, max_depth=5, n_estimators=150, subsample=0.8, colsample_bytree=0.8, gamma=0, min_child_weight= 1, reg_alpha=0)

# %%
clf1 = modelfit(clf1, train, train['Energy'], features, 'mlogloss', useTrainCV=False)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:171: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Model Report
# RMSE score (Train): 20.041465
# r2 score (Train): 0.960570
# precision score (Train): 0.677503
# accuracy score (Train): 0.677503
# <img src="data:image/png;base64,..." width="876">

# %%
pred1 = clf1.predict(test[features])
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:171: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
sub = pd.DataFrame(columns=['Observation', 'Energy'])

# %%
sub['Observation'] = test['Observation']
sub['Energy'] = pred1

# %%
sub.to_csv('xgb_class1.csv', index=False, encoding='utf-8')

# %%
def modelfit_reg(model, train_data, train_label, predictors, eval_metric, useTrainCV=True, cv_folds=10, early_stopping_rounds=50):
    
    if useTrainCV:
        xgb_param = model.get_xgb_params()
        params = {
            'objective' : xgb_param['objective'],
            'base_score' : xgb_param['base_score'],
            'colsample_bylevel' : xgb_param['colsample_bylevel'],
            'colsample_bytree' : xgb_param['colsample_bytree'],
            'gamma' : xgb_param['gamma'],
            'eta' : xgb_param['learning_rate'],
            'max_delta_step' : xgb_param['max_delta_step'],
            'max_depth' : xgb_param['max_depth'],
            'min_child_weight' : xgb_param['min_child_weight'],
            'alpha' : xgb_param['reg_alpha'],
            'lambda': xgb_param['reg_lambda'],
            'scale_pos_weight' : xgb_param['scale_pos_weight'],
            'subsample' : xgb_param['subsample'],     
        }
        dtrain = xgb.DMatrix(data=train_data[predictors], label=train_label)
        cvresult = xgb.cv(params , dtrain, num_boost_round=model.get_params()['n_estimators'], stratified=False, nfold=cv_folds, metrics=eval_metric, early_stopping_rounds=early_stopping_rounds)
        model.set_params(n_estimators=cvresult.shape[0])
        # print(cvresult)
        print("########### n_estimators = %f" % cvresult.shape[0])
    
    # Fit the algorithm on the data
    model.fit(train_data[predictors], train_label,eval_metric=eval_metric)
        
    # Predict training set:
    train_predictions = model.predict(train_data[predictors])
    
    # Predict X_valid set:
    #valid_predictions = model.predict(X_valid[predictors])
    #valid_predprob = model.predict_proba(X_valid[predictors])[:,1]
        
    # Print model report:
    print("\nModel Report")
    
    print("RMSE score (Train): %f" % math.sqrt(mean_squared_error(train_label, train_predictions)))
    print("r2 score (Train): %f" % r2_score(train_label, train_predictions))
    
    feat_imp = pd.Series(model.booster().get_fscore()).sort_values(ascending=False)
    feat_imp.plot(kind='bar', title='Feature Importances')
    plt.ylabel('Feature Importance Score')
    return model

# %%
clf2 = xgb.XGBRegressor(objective ='reg:linear',learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8, colsample_bytree=0.8, gamma=0, min_child_weight= 1, reg_alpha=0)

# %%
clf2 = modelfit_reg(clf2, train, train['Energy'], features, 'rmse')
# Out:
# ########### n_estimators = 200.000000
#
# Model Report
# RMSE score (Train): 58.705684
# r2 score (Train): 0.661680
# <img src="data:image/png;base64,..." width="800">

# %%
pred2 = clf2.predict(test[features])

# %%
sub['Observation'] = test['Observation']
sub['Energy'] = pred2

# %%
sub.to_csv('sub_xgb1.csv', index=False, encoding='utf-8')

# %%
clf2.score(train[features], train['Energy'])
# Out:
# 0.661679699557877

# %%
train.columns
# Out:
# Index(['Observation', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', 'RH_4',
#        'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9',
#        'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility',
#        'Tdewpoint', 'Energy'],
#       dtype='object')

# %%
sns.heatmap(train.corr())
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
clf3 = xgb.XGBRegressor(objective ='reg:linear',learning_rate=0.1, max_depth=5, n_estimators=5000, subsample=0.8, colsample_bytree=0.8, gamma=0, min_child_weight= 1, reg_alpha=0)

# %%
clf3 = modelfit_reg(clf3, train, train['Energy'], features, 'rmse')
# Out:
# ########### n_estimators = 4779.000000
#
# Model Report
# RMSE score (Train): 4.084512
# r2 score (Train): 0.998362
# <img src="data:image/png;base64,..." width="986">

# %%
clf3.score(train[features], train['Energy'])
# Out:
# 0.9983622483958238

# %%
pred3 = clf3.predict(test[features])

# %%
sub['Observation'] = test['Observation']
sub['Energy'] = pred3

# %%
sub.to_csv('sub_xgb2.csv', index=False, encoding='utf-8')

# %%
leak_all = pd.read_csv('appliances-energy-prediction/KAG_energydata_complete.csv')

# %%
leak_all.shape
# Out:
# (19735, 29)

# %%
leak_all.drop(['date', 'lights', 'rv1', 'rv2'], axis=1, inplace= True)

# %%
leak_all = leak_all.rename(columns={'Appliances': 'Energy'})

# %%
train['Energy'].nunique()
# Out:
# 82

# %%
leak_all['Energy'].nunique()
# Out:
# 92

# %%
leak_all['Energy'].unique()
# Out:
# array([  60,   50,   70,  230,  580,  430,  250,  100,   90,   80,  140,
#         120,  190,  110,  400,  390,  240,   40,   30,  310,  380,  370,
#          20,  260,  500,  450,  220,  170,  290,  130,  200,  210,  180,
#         350,  300,  340,  150,  330,  420,  520,  360,  270,  550,  690,
#         620,  610,  490,  410,  320,  740,  910,  510,  790,  460,  160,
#         480,  280,  560, 1080,  750,  470,  440,  800,  540,  530,  660,
#         630,  600,   10,  570,  830, 1070,  890,  590,  850,  710,  680,
#         670,  780,  640,  650,  700,  770,  720,  760,  860,  880,  730,
#         900,  820,  870,  840], dtype=int64)

# %%
(~pd.Series(train['Energy'].unique()).isin(leak_all['Energy'].unique())).sum()
# Out:
# 0

# %%
all_train = train.append(leak_all, ignore_index=True)

# %%
all_train.drop(['Observation'], axis=1, inplace=True)

# %% [markdown]
# ### 0.99991 PLB

# %%
clf4 = xgb.XGBRegressor(objective ='reg:linear',learning_rate=0.1, max_depth=10, n_estimators = 5000, subsample=1, colsample_bytree=1, gamma=0, min_child_weight= 0, reg_alpha=0)

# %%
clf4 = modelfit_reg(clf4, all_train, all_train['Energy'], features, 'rmse')
# Out:
# ########### n_estimators = 4247.000000
#
# Model Report
# RMSE score (Train): 0.055003
# r2 score (Train): 1.000000
# <img src="data:image/png;base64,..." width="897.272707824865">

# %%
clf4.get_params()
# Out:
# {'base_score': 0.5,
#  'colsample_bylevel': 1,
#  'colsample_bytree': 1,
#  'gamma': 0,
#  'learning_rate': 0.1,
#  'max_delta_step': 0,
#  'max_depth': 10,
#  'min_child_weight': 0,
#  'missing': None,
#  'n_estimators': 4247,
#  'nthread': -1,
#  'objective': 'reg:linear',
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'seed': 0,
#  'silent': True,
#  'subsample': 1}

# %%
pred4 = clf4.predict(test[features])

# %%
sub['Observation'] = test['Observation']
sub['Energy'] = pred4

# %%
sub.to_csv('sub_xgb_overfit.csv', index=False, encoding='utf-8')

# %%
clf4.score(train[features], train['Energy'])
# Out:
# 0.9999997860619501

# %%
clf4.score(all_train[features], all_train['Energy'])
# Out:
# 0.9999997081749172

# %% [markdown]
# ### not better than above

# %%
clf5 = xgb.XGBRegressor(objective ='reg:linear',learning_rate=0.1, max_depth=100, n_estimators = 100, subsample=1, colsample_bytree=1, gamma=0, min_child_weight= 0, reg_alpha=0)

# %%
clf5 = modelfit_reg(clf5, all_train, all_train['Energy'], features, 'rmse', early_stopping_rounds=30)
# Out:
# ########### n_estimators = 100.000000
#
# Model Report
# RMSE score (Train): 0.145000
# r2 score (Train): 0.999998
# <img src="data:image/png;base64,..." width="972">

# %%
clf5.score(all_train[features], all_train['Energy'])
# Out:
# 0.9999979719059655

# %%
clf6 = xgb.XGBRegressor(objective ='reg:linear',learning_rate=0.1, max_depth=50, n_estimators = 100, subsample=1, colsample_bytree=1, gamma=0, min_child_weight= 0, reg_alpha=0)

# %%
clf6 = modelfit_reg(clf6, all_train, all_train['Energy'], features , 'rmse', early_stopping_rounds=10)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt_clf1 = DecisionTreeRegressor(max_depth=50)

# %%
dt_clf1.fit(all_train[features], all_train['Energy'])
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=50, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
dt_clf1.score(all_train[features], all_train['Energy'])
# Out:
# 0.9999967888332937

# %%
pred_dt1 = dt_clf1.predict(test[features])

# %%
sub['Energy'] = pred_dt1

# %%
sub.to_csv('sub_dt.csv', index=False ,encoding='utf-8')
